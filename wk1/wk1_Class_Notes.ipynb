# %%
# tuple packing
temp = 1, 2
a, b = temp
# unpacking
a
b
# Out:
# 2

# %%
lst = ["a", "b", "c"]
# Enumerate makes tuples of the index
for elem in enumerate(lst):
    print(elem)
# Out:
# (0, 'a')
# (1, 'b')
# (2, 'c')

# %%
# packing and unpacking Pythonically
tup = ('Name', 43)
name, age = tup
age #outputs just the age
# Out:
# 43

# %%
txt = 'but soft what light in yonder window breaks'
words = txt.split()
print(words)

t = list()
for word in words:
   t.append((len(word), word)) # pack the tuple (decorate)

t.sort(reverse=True) # sort the tuple (sort)

res = list()    # print out the result (undecorate)
for length, word in t:
    res.append(word)

print(res)

# %% [markdown]
# ## This is "cheating" using the Counter function:

# %%
filename = input("input filename ")
file = open(filename, 'r')
from collections import Counter

addr_lst = []
for line in file:
    if "From" in line: 
        a = line.split()
        
        if len(a) > 2:
            a = line.split()
            addr_lst.append(a[1])
                 
        counted_lst = []
        c = Counter(addr_lst)
                  
print(c)

# %% [markdown]
# ## This is the "real" code using tuples:

# %%
filename = input("input filename ")
file = open(filename, 'r')
from collections import Counter

addr_lst = []
for line in file:
    if "From" in line: 
        a = line.split()
        
        if len(a) > 2:
            a = line.split()
            addr_lst.append(a[1])
                 
        counted_lst = []
        for item in range(len(addr_lst)):
            addr_count = addr_lst[item], addr_lst.count(addr_lst[item])
            counted_lst.append(addr_count)
            
        counted_lst.sort(reverse = True)
        
        #print(counted_lst)
# Out:
# input filename mbox.txt
# [('stephen.marquard@uct.ac.za', 29), ('louis@media.berkeley.edu', 24), ('zqian@umich.edu', 195), ('rjlowe@iupui.edu', 90), ('zqian@umich.edu', 195), ('rjlowe@iupui.edu', 90), ('cwen@iupui.edu', 158), ('cwen@iupui.edu', 158), ('gsilver@umich.edu', 28), ('gsilver@umich.edu', 28), ('zqian@umich.edu', 195), ('gsilver@umich.edu', 28), ('wagnermr@iupui.edu', 44), ('zqian@umich.edu', 195), ('antranig@caret.cam.ac.uk', 18), ('gopal.ramasammycook@gmail.com', 25), ('david.horwitz@uct.ac.za', 67), ('david.horwitz@uct.ac.za', 67), ('david.horwitz@uct.ac.za', 67), ('david.horwitz@uct.ac.za', 67), ('stephen.marquard@uct.ac.za', 29), ('louis@media.berkeley.edu', 24), ('louis@media.berkeley.edu', 24), ('ray@media.berkeley.edu', 32), ('cwen@iupui.edu', 158), ('cwen@iupui.edu', 158), ('cwen@iupui.edu', 158), ('ray@media.berkeley.edu', 32), ('cwen@iupui.edu', 158), ('zqian@umich.edu', 195), ('cwen@iupui.edu', 158), ('zqian@umich.edu', 195), ('zqian@umich.edu', 195), ('zqian@umich.edu', 195), 